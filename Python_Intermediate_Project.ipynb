# %%
# INTERMEDIATE PYTHON PROJECT //

# %%
'''
Questions :

Q1.  What is the average median income of the data set and check the distribution 
     of data using appropriate plots. Please explain the distribution of the 
     plot.
    
Q2.  Draw an appropriate plot to see the distribution of housing_median_age 
     and explain your observavations.
    
Q3.  Show with the help of visualisation, how median_income and 
     median_house_values are related?
    
Q4.  Create a data set by deleting the corresponding examples from the data set
     for which total_bedrooms are not available.
    
Q5.  Create a data set by filling the missing data with the mean value of the
     total_bedrooms in the original data set.
    
Q6.  Write a programming construct (create a user defined function) to calculate
     the median value of the data set wherever required.
    
Q7.  Plot latitude versus longitude and explain your observations.

Q8.  Create a data set for which the ocean_proximity is 'Near_ocean'.

Q9.  Find the mean and median of the median income for the data set created in
     question 8.
    
Q10. Please create a new column named total_bedroom_size. If the total bedrooms
     is 10 or less, it should be quoted as small. If the total bedrooms is 11
     or more but less than 1000, it should be medium, otherwise it should be 
     considered large.
     
'''

# %%
# 2198208-housing_(1)

# %%
import pandas as pd # importing pandas library to import

df = pd.read_excel('C:\\Users\\ASUS\\Python Jupiter\\\\2198208-housing_(1).xlsx')
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
'''
Q1.  What is the average median income of the data set and check the distribution 
     of data using appropriate plots. Please explain the distribution of the 
     plot.
'''

avg_med_inc = df.median_income.mean()

print('The average median income of the given data set is: ', avg_med_inc)
# Out:
# The average median income of the given data set is:  3.8706710029069766

# %%
# The average median income data is Continuous (point value)
# Histogram

# %%
ax = sns.histplot(df.median_income, bins = 15, kde = True, color="cyan", edgecolor = 'grey')
ax.lines[0].set_color('red')
plt.xlabel('Median Income      -------->')
plt.ylabel('Count / Frequency      -------->')
plt.title('Distribution of Average Median Income')
plt.grid(linestyle=':')
plt.show()

# the peak of the kernel density estimation curve or bell curve shows the average median income

# %%
print(df.head()) # gives first 5 records
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY

# %%
'''
Q2.  Draw an appropriate plot to see the distribution of housing_median_age 
     and explain your observavations.
'''

# It is a discrete variable (count)

sns.set_style('whitegrid')
sns.histplot(df['housing_median_age'], kde = True, color ='green', bins = 30)
plt.xlabel('Housing Median Age      -------->')
plt.ylabel('Count / Frequency      -------->')
plt.title('Distribution of Housing Median Age')
plt.show()

# Now looking at this we can say that most of the total bill given lies between 10 and 20.

# %%
df.housing_median_age.mean() # as you can see mean age falls between 25 - 30
# Out:
# 28.639486434108527

# %%
'''
Q3.  Show with the help of visualisation, how median_income and 
     median_house_values are related?
'''
plt.scatter(df.median_income, df.median_house_value)
plt.xlabel('MEDIAN INCOME      -------->')
plt.ylabel('MEDIAN HOUSE VALUE      -------->')
plt.title('Median Income Vs. Median Household Values')

plt.show()

# %%
'''
Q3.  Show with the help of visualisation, how median_income and 
     median_house_values are related?
'''
feats = ['median_income', 'median_house_value']

sns.pairplot(df[feats])
#       have to put in third bracket

# The Seaborn Pairplot allows us to plot pairwise relationships between variables 
# within a dataset

plt.show()

# most of the data can be found around the given area which shows the relation between median
# income and median house values

# %%
'''
Q4.  Create a data set by deleting the corresponding examples from the data set
     for which total_bedrooms are not available.
'''

# Looking for missing data in the given dataframe

# creating series True for NaN values in total_bedrooms
missing_df = pd.isnull(df["total_bedrooms"])
	
# filtering data
# displaying data only with Gender = NaN
df[missing_df]

# these 207 rows must not be there in the new data set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 290      -122.16     37.77                  47         1256             NaN
# 341      -122.17     37.75                  38          992             NaN
# 538      -122.28     37.78                  29         5154             NaN
# 563      -122.24     37.75                  45          891             NaN
# 696      -122.10     37.69                  41          746             NaN
# ...          ...       ...                 ...          ...             ...
# 20267    -119.19     34.20                  18         3620             NaN
# 20268    -119.18     34.19                  19         2393             NaN
# 20372    -118.88     34.17                  15         4260             NaN
# 20460    -118.75     34.29                  17         5512             NaN
# 20484    -118.72     34.28                  17         3051             NaN
#
# ...

# %%
df.tail() # total number of records are 20640 (as it begins from zero)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income  median_house_value  \
# 20635         845         330         1.5603               78100
# 20636         356         114         2.5568               77100
# 20637        1007         433         1.7000               92300
# 20638         741         349         1.8672               84700
# 20639        1387         530         2.3886               89400
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# ...

# %%
# Just to check if our new data is returning exact rows or not
print(20640 - 20433) # (207 missing records)
# Out:
# 207

# %%
new_df = pd.notnull(df['total_bedrooms']) 
# checking where it is not null

df[new_df] # printing the new dataframe with deleted null values returns 20433 which is
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
'''
Q5.  Create a data set by filling the missing data with the mean value of the
     total_bedrooms in the original data set.
'''
# importing pandas package 
import pandas as pd 

# making data frame from excel file 
data = pd.read_excel('C:\\Users\\ASUS\\Python Jupiter\\\\2198208-housing_(1).xlsx')

# calculating the mean of total_bedrooms in the given dataset
mean_tot_bed = data.total_bedrooms.mean()

print(mean_tot_bed)
# Out:
# 537.8705525375618

# %%
# fillna() - function replaces NaN values with some value of their own
# filling missing value using fillna()  
data['total_bedrooms'].fillna(mean_tot_bed, inplace = True)

data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
# check 
x = pd.isnull(data["total_bedrooms"])

data[x]

# Hence no data is null
# Out:
# Empty DataFrame
# Columns: [longitude, latitude, housing_median_age, total_rooms, total_bedrooms, population, households, median_income, median_house_value, ocean_proximity]
# Index: []

# %%
'''
Q6.  Write a programming construct (create a user defined function) to calculate
     the median value of the data set wherever required.
'''
# importing pandas package 
import pandas as pd 

# making data frame from excel file 
df = pd.read_excel('C:\\Users\\ASUS\\Python Jupiter\\\\2198208-housing_(1).xlsx')


def Median():
    print('MEDIAN CALCULATOR:')
    print('(Enter a specific number alongside the given options to calculate the median of the dataset)')
    print('longitude - 1 \nlatitude - 2	\nhousing_median_age - 3 \ntotal_rooms - 4')
    print('total_bedrooms - 5 \npopulation - 6 \nhouseholds - 7 \nmedian_income - 8	\nmedian_house_value - 9')
    choice = int(input('\nEnter your choice: ')) # taking input
    
    if (choice > 0) & (choice <= 9):
        
        if (choice == 1):
            res = df.longitude.median()
            print('The median of Longitudes is: ', res)
            
        if (choice == 2):
            res = df.latitude.median()
            print('The median of Latitude is: ', res)
            
        if (choice == 3):
            res = df.housing_median_age.median()
            print('The median of Housing Median Age is: ', res)  
            
        if (choice == 4):
            res = df.total_rooms.median()
            print('The median of Total Rooms is: ', res)
            
        if (choice == 5):
            res = df.total_bedrooms.median()
            print('The median of Total Bedrooms is: ', res)
            
        if (choice == 6):
            res = df.population.median()
            print('The median of Population is: ', res)
            
        if (choice == 7):
            res = df.households.median()
            print('The median of Households is: ', res)   
            
        if (choice == 8):
            res = df.median_income.median()
            print('The median of Median Income is: ', res)
            
        if (choice == 9):
            res = df.median_house_value.median()
            print('The median of Median House Value is: ', res)            
            
    else:
        print('Invalid Input')
        
Median()
# calling the function
# Out:
# MEDIAN CALCULATOR:
# (Enter a specific number alongside the given options to calculate the median of the dataset)
# longitude - 1
# latitude - 2
# housing_median_age - 3
# total_rooms - 4
# total_bedrooms - 5
# population - 6
# households - 7
# median_income - 8
# median_house_value - 9
# Enter your choice:  9
# The median of Median House Value is:  179700.0

# %%
'''
Q7.  Plot latitude versus longitude and explain your observations.
'''
# importing the libraries
import plotly.express as px
import pandas as pd

# making data frame from excel file 
data = pd.read_excel('C:\\Users\\ASUS\\Python Jupiter\\\\2198208-housing_(1).xlsx')

# plotting map using plotly
fig = px.scatter_geo(data, lat = 'latitude', lon = 'longitude')

# setting title for the map
fig.update_layout(title = 'Latitude Versus Longitude', title_x = 0.5)

# displaying the map
fig.show()

# %%
# SECOND PLOT RO EXPLAIN THE MAP BETTER

# importing the libraries
import plotly.express as px
import pandas as pd

# making data frame from excel file 
data = pd.read_excel('C:\\Users\\ASUS\\Python Jupiter\\\\2198208-housing_(1).xlsx')

x = data.latitude
y = data.longitude
plt.scatter(x,y, marker = '*', color = 'blue')
plt.xlabel('Latitude   -------------->')
plt.ylabel('Longitude    -------------->')
plt.title("Locational Graph")
plt.show()

# %%
'''
Q8.  Create a data set for which the ocean_proximity is 'Near_ocean'.
'''

# importing the libraries
import pandas as pd

# making data frame from excel file 
df = pd.read_excel('C:\\Users\\ASUS\\Python Jupiter\\\\2198208-housing_(1).xlsx')

ocean = df[df['ocean_proximity'] == 'NEAR OCEAN'] # where Ocean Proximity is Near Ocean

ocean # printing the required dataset
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1850     -124.17     41.80                  16         2739           480.0
# 1851     -124.30     41.80                  19         2672           552.0
# 1852     -124.23     41.75                  11         3159           616.0
# 1853     -124.21     41.77                  17         3461           722.0
# 1854     -124.19     41.78                  15         3140           714.0
# ...          ...       ...                 ...          ...             ...
# 20380    -118.83     34.14                  16         1316           194.0
# 20381    -118.83     34.14                  16         1956           312.0
# 20423    -119.00     34.08                  17         1822           438.0
# 20424    -118.75     34.18                   4        16704          2704.0
# 20425    -118.75     34.17                  18         6217           858.0
#
# ...

# %%
'''
Q9.  Find the mean and median of the median income for the data set created in
     question 8.
    
'''
mean = ocean.median_income.mean()
median = ocean.median_income.median()
print(ocean.head())
print('\nFor the Median-Income of the Near-Ocean Data Set: ')
print('The required mean is: ', mean)
print('The required median is:', median)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1850    -124.17     41.80                  16         2739           480.0
# 1851    -124.30     41.80                  19         2672           552.0
# 1852    -124.23     41.75                  11         3159           616.0
# 1853    -124.21     41.77                  17         3461           722.0
# 1854    -124.19     41.78                  15         3140           714.0
#
#       population  households  median_income  median_house_value  \
# 1850        1259         436         3.7557              109400
# 1851        1298         478         1.9797               85800
# 1852        1343         479         2.4805               73200
# 1853        1947         647         2.5795               68400
# 1854        1645         640         1.6654               74600
#
#      ocean_proximity
# 1850      NEAR OCEAN
# 1851      NEAR OCEAN
# 1852      NEAR OCEAN
# 1853      NEAR OCEAN
# ...

# %%
'''
Q10. Please create a new column named total_bedroom_size. If the total bedrooms
     is 10 or less, it should be quoted as small. If the total bedrooms is 11
     or more but less than 1000, it should be medium, otherwise it should be 
     considered large.
'''

# importing the libraries
import pandas as pd

# making data frame from excel file 
data = pd.read_excel('C:\\Users\\ASUS\\Python Jupiter\\\\2198208-housing_(1).xlsx')

size = [] # declaring a list

for i in data['total_bedrooms']:
    if (i <= 10):
        size.append('SMALL')       # append the element to the end of the list
    elif (i == 11) | (i < 1000):
        size.append('MEDIUM')
    elif (i > 1000):
        size.append('LARGE')
    else:                           # For Null Values
        size.append('None')
        
# print(size)

# Using 'tota_bedroom_size' as the column name
# and equating it to the list
data['total_bedroom_size'] = size

data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
# check = data[data['total_bedroom_size'] == 'None']

# check

# %%
# DONE
